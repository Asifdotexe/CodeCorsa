# %%
import requests
from bs4 import BeautifulSoup

# %%
keywords = "Python"
location = "Russia"

# %%
url = f"https://www.linkedin.com/jobs/search/?keywords={keywords}&location={location}"

# %%
print(url)
# Out:
# https://www.linkedin.com/jobs/search/?keywords=Python&location=Russia
